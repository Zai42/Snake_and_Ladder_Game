# %% [markdown]
# ***Topic:*** Create a game using python
#
#
# **Submitted by:** Musab Bin Usman
#
#
# **Roll no:** 2kx9 cs 19
#
#
# **Submitted to:** Ma'am Ujala Jamil
#
#
# **Subject:** Artificial Intelligence (Lab)
#
#
# **Date of submission:** 07 December 2022

# %%
import random

# %%
#p1pos,n1,m1=0,cp1,minus1,plus1,plus2,minus2,p2pos,n2,m2=0,cp2;
def posforp1():
  p1pos=random.randint(1,6);
  return p1pos
def posforp2():
  p2pos = random.randint(1,6);
  return p2pos
def posforplayers():
  m1 = 0
  m2 = 0
     #Player 1
  for i in range(0,99):  #for(i=0;i<=100;i++):
    print("\n Your Turn \n")
    n1=m1
    p1roll = input("P1 Enter 'Roll' to roll the dice: ")
    if((p1roll=="ROLL")or(p1roll=="roll")or(p1roll=="Roll")):
      dice_value = posforp1()
      print("Value on dice is: ",dice_value) 
      cp1=n1+dice_value;
    if((cp1==15)or(cp1==25)or(cp1==35)or(cp1==45)or(cp1==49)):
      cp1=cp1-5
      print("Current position of Player 1= ",cp1,"(Snake=(-5))")
    if((cp1==21)or(cp1==31)or(cp1==41)or(cp1==27)or(cp1==37)):
      cp1=cp1+5
      print("Current position of Player 1= ",cp1,"(Ladder=(+5))")
    else:
      print("Current position of Player 1=",cp1);
    m1=cp1

    print("\n PC Turn \n")
    n2 = m2
    pos_for_dice_2 = posforp2()
    print("Value on dice is: ",pos_for_dice_2) 
    cp2=n2+pos_for_dice_2
    if((cp2==15)or(cp2==25)or(cp2==35)or(cp2==45)or(cp2==49)):
      cp2=cp2-5
      print("Current position of PC is= ",cp2,"(Snake=(-5))")
    if((cp2==21)or(cp2==31)or(cp2==41)or(cp2==27)or(cp2==37)):
     cp2=cp2+5
     print("Current position of PC is= ",cp2,"(Ladder=(+5))")
    else:
     print("Current position of PC=",cp2)
    m2=cp2
    if((cp1<50)and(cp2<50)):
      pass
    elif((cp1>=50)or(cp2>=50)):
      if(cp1>=50):
        print("\t \t----------Congratulations! Player 1 wins!----------")
      elif(cp2>=50):
        print("\t \t----------Computer has won the Game!----------")
        break
posforplayers()
